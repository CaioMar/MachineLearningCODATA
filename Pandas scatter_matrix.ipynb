# %%
import numpy as np
import pandas as pd
from pandas.tools.plotting import scatter_matrix
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.stats.api as sms
from sklearn.tree import DecisionTreeClassifier
sns.set_style('whitegrid')

# %%
df = pd.read_csv('mtcars.csv')

# %%
df.hist(bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2ada6cbe10>,
# ...
#       dtype=object)

# %%
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
scatter_matrix(df,figsize=(12,8))
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """Entry point for launching an IPython kernel.

# %%
df = pd.read_csv('/home/caio/Desktop/CODA_DSschool/dataSaoPaulo2018/data/Advertising.csv')

# %%
spector_data = sm.datasets.spector.load()

# %%
spector_data.exog = sm.add_constant(spector_data.exog, prepend=False)

# %%
mod = sm.OLS(spector_data.endog, spector_data.exog)
res = mod.fit()
print(res.summary())

# %%
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.416
# Model:                            OLS   Adj. R-squared:                  0.353
# Method:                 Least Squares   F-statistic:                     6.646
# Date:                Tue, 11 Dec 2018   Prob (F-statistic):            0.00157
# Time:                        12:17:28   Log-Likelihood:                -12.978
# No. Observations:                  32   AIC:                             33.96
# Df Residuals:                      28   BIC:                             39.82
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.4639      0.162      2.864      0.008       0.132       0.796
# ...

# %%
df.drop('Unnamed: 0', axis=1,inplace=True)

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
Xtrain = np.array(df['TV']).reshape(-1,1)
ytrain = np.array(df['sales'])

# %%
lm = LinearRegression()
lm.fit(Xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm.predict(Xtrain)
# Out:
# array([17.97077451,  9.14797405,  7.85022376, 14.23439457, 15.62721814,
#         7.44616232,  9.76595037, 12.74649773,  7.44140866, 16.53041431,
#        10.17476548, 17.23871025,  8.16396559, 11.66741599, 16.73482186,
#        16.32125309, 10.25557777, 20.40940417, 10.32212907, 14.03474068,
#        17.41459582, 18.31779199,  7.6600772 , 17.88520856,  9.99412625,
#        19.52997632, 13.82557947, 18.44614092, 18.85970969, 10.38868036,
#        20.95607553, 12.39948025, 11.653155  , 19.65832525, 11.58185004,
#        20.85149492, 19.72012288, 10.58358059,  9.08142275, 17.87094757,
#        16.65876324, 15.44657891, 20.98935118, 16.86792445,  8.22576322,
#        15.35625929, 11.2966302 , 18.43663359, 17.83291826, 10.21279479,
#        16.53041431, 11.80527225, 17.31952254, 15.71278409, 19.52046899,
#        16.48763133,  7.37961102, 13.50708398, 17.05331735, 17.04856369,
#         9.57580381, 19.45391769, 18.4081116 , 11.91460652, 13.26464711,
# ...

# %%
model = lm.coef_*Xtrain+lm.intercept_

# %%
plt.plot(Xtrain,ytrain,'.')
plt.plot(Xtrain,lm.predict(Xtrain))
plt.xlabel('TV')
plt.ylabel('sales')
plt.show()

# %%
plt.plot()

# %%
cols = ['TV','radio','newspaper']

# %%
Xtrain = df[cols]

# %%
Xtrain = sm.add_constant(Xtrain, prepend=False)
mod = sm.OLS(ytrain, Xtrain)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Tue, 11 Dec 2018   Prob (F-statistic):           1.58e-96
# Time:                        13:09:33   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# TV             0.0458      0.001     32.809      0.000       0.043       0.049
# ...

# %%
sms.jarque_bera(res.resid)
# Out:
# (151.2414204760403,
#  1.439934794237808e-33,
#  -1.3273536543621305,
#  6.331891289062539)

# %%
irisdf = pd.read_csv('iris.csv')

# %%
irisdf.drop(columns=irisdf.columns[0],axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
ytrain = np.array(irisdf['Species'] == 'setosa')
Xtrain = np.array(irisdf.drop("Species",axis=1))

# %%
treeclf = DecisionTreeClassifier(max_depth=2)
treeclf.fit(Xtrain,ytrain)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=2,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn.tree import export_graphviz

export_graphviz(treeclf,out_file='iris.dot',feature_names=irisdf.columns[:-1],class_names=['not setosa','setosa'],filled=True)

# %%
from sklearn.decomposition import PCA

# %%
X = PCA(n_components=2).fit_transform(Xtrain)

# %%
ytrain[ytrain==1]=1.0
ytrain[ytrain==0]=0.0

# %%
ytrain = np.asarray(ytrain,dtype=int)

# %%
plt.scatter(X[:,0],X[:,1],c=ytrain)

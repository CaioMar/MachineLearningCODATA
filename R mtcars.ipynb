# %%
library('tidyverse')
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 2.2.1     ✔ purrr   0.2.4
# ✔ tibble  1.4.2     ✔ dplyr   0.7.4
# ✔ tidyr   0.8.0     ✔ stringr 1.3.0
# ✔ readr   1.1.1     ✔ forcats 0.3.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
head(mtcars)
# Out:
#                   mpg  cyl disp hp  drat wt    qsec  vs am gear carb
# Mazda RX4         21.0 6   160  110 3.90 2.620 16.46 0  1  4    4
# Mazda RX4 Wag     21.0 6   160  110 3.90 2.875 17.02 0  1  4    4
# Datsun 710        22.8 4   108   93 3.85 2.320 18.61 1  1  4    1
# Hornet 4 Drive    21.4 6   258  110 3.08 3.215 19.44 1  0  3    1
# Hornet Sportabout 18.7 8   360  175 3.15 3.440 17.02 0  0  3    2
# Valiant           18.1 6   225  105 2.76 3.460 20.22 1  0  3    1

# %%
pairs(mtcars, lower.panel = NULL) #Observação 1:10, features...
# Out:
# plot without title

# %%
?mtcars

# %%
model2 <- lm(mtcars$mpg ~ mtcars$wt)

# %%
write_csv(mtcars,'mtcars.csv')

# %%
model <- lm(mtcars$mpg ~ mtcars$disp)
coef(model)
# Out:
# (Intercept) mtcars$disp
# 29.59985476 -0.04121512

# %%
model <- lm(mtcars$mpg ~ mtcars$disp)
plot(y = mtcars$mpg, x = mtcars$disp, xlab = "Engine Size (cubic inches)",
ylab = "Fuel Efficiency (Miles per Gallon)", main = "Fuel Efficiency From
the `mtcars` Dataset")
abline(a = coef(model[1]), b = coef(model)[2], lty = 2)
# Out:
# Plot with title “Fuel Efficiency From
# the `mtcars` Dataset”

# %%
summary(model)
# Out:
# Call:
# lm(formula = mtcars$mpg ~ mtcars$disp)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.8922 -2.2022 -0.9631  1.6272  7.2305
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 29.599855   1.229720  24.070  < 2e-16 ***
# mtcars$disp -0.041215   0.004712  -8.747 9.38e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.251 on 30 degrees of freedom
# Multiple R-squared:  0.7183,	Adjusted R-squared:  0.709
# F-statistic: 76.51 on 1 and 30 DF,  p-value: 9.38e-10

# %%
summary(model2)
# Out:
# Call:
# lm(formula = mtcars$mpg ~ mtcars$wt)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.5432 -2.3647 -0.1252  1.4096  6.8727
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  37.2851     1.8776  19.858  < 2e-16 ***
# mtcars$wt    -5.3445     0.5591  -9.559 1.29e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.046 on 30 degrees of freedom
# Multiple R-squared:  0.7528,	Adjusted R-squared:  0.7446
# F-statistic: 91.38 on 1 and 30 DF,  p-value: 1.294e-10

# %%
df <- read.csv('~/Desktop/CODA_DSschool/dataSaoPaulo2018/data/Advertising.csv', header=T, colClasses=c('NULL',NA,NA,NA,NA))

# %%
df
# Out:
#     TV    radio newspaper sales
# 1   230.1 37.8   69.2     22.1
# 2    44.5 39.3   45.1     10.4
# 3    17.2 45.9   69.3      9.3
# 4   151.5 41.3   58.5     18.5
# 5   180.8 10.8   58.4     12.9
# 6     8.7 48.9   75.0      7.2
# 7    57.5 32.8   23.5     11.8
# 8   120.2 19.6   11.6     13.2
# 9     8.6  2.1    1.0      4.8
# 10  199.8  2.6   21.2     10.6
# 11   66.1  5.8   24.2      8.6
# 12  214.7 24.0    4.0     17.4
# 13   23.8 35.1   65.9      9.2
# 14   97.5  7.6    7.2      9.7
# 15  204.1 32.9   46.0     19.0
# 16  195.4 47.7   52.9     22.4
# 17   67.8 36.6  114.0     12.5
# 18  281.4 39.6   55.8     24.4
# 19   69.2 20.5   18.3     11.3
# 20  147.3 23.9   19.1     14.6
# 21  218.4 27.7   53.4     18.0
# 22  237.4  5.1   23.5     12.5
# 23   13.2 15.9   49.6      5.6
# 24  228.3 16.9   26.2     15.5
# 25   62.3 12.6   18.3      9.7
# 26  262.9  3.5   19.5     12.0
# 27  142.9 29.3   12.6     15.0
# 28  240.1 16.7   22.9     15.9
# 29  248.8 27.1   22.9     18.9
# 30   70.6 16.0   40.8     10.5
# ⋮   ⋮     ⋮     ⋮         ⋮
# 171  50.0 11.6  18.4       8.4
# 172 164.5 20.9  47.4      14.5
# 173  19.6 20.1  17.0       7.6
# 174 168.4  7.1  12.8      11.7
# 175 222.4  3.4  13.1      11.5
# 176 276.9 48.9  41.8      27.0
# 177 248.4 30.2  20.3      20.2
# 178 170.2  7.8  35.2      11.7
# 179 276.7  2.3  23.7      11.8
# 180 165.6 10.0  17.6      12.6
# 181 156.6  2.6   8.3      10.5
# 182 218.5  5.4  27.4      12.2
# 183  56.2  5.7  29.7       8.7
# 184 287.6 43.0  71.8      26.2
# 185 253.8 21.3  30.0      17.6
# 186 205.0 45.1  19.6      22.6
# 187 139.5  2.1  26.6      10.3
# 188 191.1 28.7  18.2      17.3
# 189 286.0 13.9   3.7      15.9
# 190  18.7 12.1  23.4       6.7
# 191  39.5 41.1   5.8      10.8
# 192  75.5 10.8   6.0       9.9
# 193  17.2  4.1  31.6       5.9
# 194 166.8 42.0   3.6      19.6
# 195 149.7 35.6   6.0      17.3
# 196  38.2  3.7  13.8       7.6
# 197  94.2  4.9   8.1       9.7
# 198 177.0  9.3   6.4      12.8
# 199 283.6 42.0  66.2      25.5
# 200 232.1  8.6   8.7      13.4

# %%
pairs(df, lower.panel = NULL)
# Out:
# plot without title

# %%
df.lm <- lm(df$sales ~ df$TV)
summary(df.lm)
# Out:
# Call:
# lm(formula = df$sales ~ df$TV)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8.3860 -1.9545 -0.1913  2.0671  7.2124
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 7.032594   0.457843   15.36   <2e-16 ***
# df$TV       0.047537   0.002691   17.67   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.259 on 198 degrees of freedom
# Multiple R-squared:  0.6119,	Adjusted R-squared:  0.6099
# F-statistic: 312.1 on 1 and 198 DF,  p-value: < 2.2e-16

# %%
df.lm2 <- lm(df$sales ~ df$newspaper)
summary(df.lm2)
# Out:
# Call:
# lm(formula = df$sales ~ df$newspaper)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -11.2272  -3.3873  -0.8392   3.5059  12.7751
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  12.35141    0.62142   19.88  < 2e-16 ***
# df$newspaper  0.05469    0.01658    3.30  0.00115 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 5.092 on 198 degrees of freedom
# Multiple R-squared:  0.05212,	Adjusted R-squared:  0.04733
# F-statistic: 10.89 on 1 and 198 DF,  p-value: 0.001148

# %%
plot(x=df$newspaper, y=df$sales)
abline(df.lm)
# Out:
# plot without title

# %%
complex_formula <- sales ~ TV + radio + newspaper
df.lm4 <- lm(formula=complex_formula, data = df)
summary(df.lm4)
# Out:
# Call:
# lm(formula = complex_formula, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8.8277 -0.8908  0.2418  1.1893  2.8292
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.938889   0.311908   9.422   <2e-16 ***
# TV           0.045765   0.001395  32.809   <2e-16 ***
# radio        0.188530   0.008611  21.893   <2e-16 ***
# newspaper   -0.001037   0.005871  -0.177     0.86
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.686 on 196 degrees of freedom
# Multiple R-squared:  0.8972,	Adjusted R-squared:  0.8956
# F-statistic: 570.3 on 3 and 196 DF,  p-value: < 2.2e-16

# %%
Prestige
# Out:
# Error in eval(expr, envir, enclos): object 'Prestige' not found
# Traceback:

# %%
# Out:
# Error in library("cars"): there is no package called ‘cars’
# Traceback:
#
# 1. library("cars")
# 2. stop(txt, domain = NA)

# %%
installed.packages(Prestige)
library(car)
# Out:
# Error in installed.packages(Prestige): object 'Prestige' not found
# Traceback:
#
# 1. installed.packages(Prestige)

# %%
Prestige
# Out:
# Error in eval(expr, envir, enclos): object 'Prestige' not found
# Traceback:

# %%
library(car)
# Out:
# Error in library(car): there is no package called ‘car’
# Traceback:
#
# 1. library(car)
# 2. stop(txt, domain = NA)

# %%
dfpcars <- read.csv('~/Downloads/Prestige.csv')

# %%
head(dfpcars)
# Out:
#   X                   education income women prestige census type
# 1 gov.administrators  13.11     12351  11.16 68.8     1113   prof
# 2 general.managers    12.26     25879   4.02 69.1     1130   prof
# 3 accountants         12.77      9271  15.70 63.4     1171   prof
# 4 purchasing.officers 11.42      8865   9.11 56.8     1175   prof
# 5 chemists            14.62      8403  11.68 73.5     2111   prof
# 6 physicists          15.64     11030   5.13 77.6     2113   prof

# %%
pairs(dfpcars, lower.panel = NULL)
# Out:
# plot without title

# %%
complex_formula <- prestige ~ income + education
dfpcars.lm <- lm(formula=complex_formula, data = dfpcars)
summary(dfpcars.lm)
# Out:
# Call:
# lm(formula = complex_formula, data = dfpcars)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -19.4040  -5.3308   0.0154   4.9803  17.6889
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -6.8477787  3.2189771  -2.127   0.0359 *
# income       0.0013612  0.0002242   6.071 2.36e-08 ***
# education    4.1374444  0.3489120  11.858  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 7.81 on 99 degrees of freedom
# Multiple R-squared:  0.798,	Adjusted R-squared:  0.7939
# F-statistic: 195.6 on 2 and 99 DF,  p-value: < 2.2e-16

# %%
dfpcars.lm2 <- lm(dfpcars$prestige ~ dfpcars$income)
summary(dfpcars.lm2)
# Out:
# Call:
# lm(formula = dfpcars$prestige ~ dfpcars$income)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -33.007  -8.378  -2.378   8.432  32.084
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)    2.714e+01  2.268e+00   11.97   <2e-16 ***
# dfpcars$income 2.897e-03  2.833e-04   10.22   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 12.09 on 100 degrees of freedom
# Multiple R-squared:  0.5111,	Adjusted R-squared:  0.5062
# F-statistic: 104.5 on 1 and 100 DF,  p-value: < 2.2e-16

# %%
dfpcars.lm3 <- lm(dfpcars$prestige ~ dfpcars$education)
summary(dfpcars.lm3)
# Out:
# Call:
# lm(formula = dfpcars$prestige ~ dfpcars$education)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -26.0397  -6.5228   0.6611   6.7430  18.1636
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -10.732      3.677  -2.919  0.00434 **
# dfpcars$education    5.361      0.332  16.148  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.103 on 100 degrees of freedom
# Multiple R-squared:  0.7228,	Adjusted R-squared:   0.72
# F-statistic: 260.8 on 1 and 100 DF,  p-value: < 2.2e-16

# %%
pop <- data.frame(uspop)

# %%
uspop
# Out:
# Time Series:
# Start = 1790
# End = 1970
# Frequency = 0.1
#  [1]   3.93   5.31   7.24   9.64  12.90  17.10  23.20  31.40  39.80  50.20
# [11]  62.90  76.00  92.00 105.70 122.80 131.70 151.30 179.30 203.20

# %%
pop$year <- seq(from = 1790, to = 1970, by = 10)
pop$uspop <- as.numeric(pop$uspop)

# %%
plot(y = pop$uspop, x = pop$year, main = "United States Population From 1790 to
1970",
xlab = "Year", ylab = "Population")
# Out:
# Plot with title “United States Population From 1790 to
# 1970”

# %%
lm1 <- lm(pop$uspop ~ pop$year)
summary(lm1)
# Out:
# Call:
# lm(formula = pop$uspop ~ pop$year)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -19.569 -14.776  -2.933   9.501  36.345
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.958e+03  1.428e+02  -13.71 1.27e-10 ***
# pop$year     1.079e+00  7.592e-02   14.21 7.29e-11 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 18.12 on 17 degrees of freedom
# Multiple R-squared:  0.9223,	Adjusted R-squared:  0.9178
# F-statistic: 201.9 on 1 and 17 DF,  p-value: 7.286e-11

# %%
plot(y = pop$uspop, x = pop$year, main = "United States Population From 1790 to
1970",
xlab = "Year", ylab = "Population")
abline(a = coef(lm1[1]), b = coef(lm1)[2], lty = 2, col = "red")
# Out:
# Plot with title “United States Population From 1790 to
# 1970”

# %%
lm2 <- lm(pop$uspop ~ poly(pop$year, 2))
summary(lm2)
# Out:
# Call:
# lm(formula = pop$uspop ~ poly(pop$year, 2))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.5997 -0.7105  0.2669  1.4065  3.9879
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         69.7695     0.6377  109.40  < 2e-16 ***
# poly(pop$year, 2)1 257.5420     2.7798   92.65  < 2e-16 ***
# poly(pop$year, 2)2  73.8974     2.7798   26.58 1.14e-14 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.78 on 16 degrees of freedom
# Multiple R-squared:  0.9983,	Adjusted R-squared:  0.9981
# F-statistic:  4645 on 2 and 16 DF,  p-value: < 2.2e-16

# %%
plot(y = pop$uspop, x = pop$year, main = "United States Population From 1790 to
1970",
xlab = "Year", ylab = "Population")
lines(sort(pop$year), fitted(lm2)[order(pop$year)], col = "blue",
lty = 2)
# Out:
# Plot with title “United States Population From 1790 to
# 1970”

# %%
plot(y=residuals(lm2),x=fitted(lm2))
# Out:
# plot without title

# %%
mean(residuals(lm2))
# Out:
# [1] -7.886144e-17

# %%
sd(residuals(lm2))
# Out:
# [1] 2.620806

# %%
cars.logistic <- glm(am ~ mpg + wt, data = mtcars, family = "binomial")

# %%
summary(cars.logistic)
# Out:
# Call:
# glm(formula = am ~ mpg + wt, family = "binomial", data = mtcars)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -2.50806  -0.45191  -0.04684   0.24664   2.01168
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)  25.8866    12.1935   2.123   0.0338 *
# mpg          -0.3242     0.2395  -1.354   0.1759
# wt           -6.4162     2.5466  -2.519   0.0118 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 43.230  on 31  degrees of freedom
# Residual deviance: 17.184  on 29  degrees of freedom
# AIC: 23.184
#
# Number of Fisher Scoring iterations: 7

# %%
plot(x = mtcars$mpg, y= mtcars$am)
lines(y = fitted(cars.logistic), x= mtcars$mpg)
# Out:
# plot without title

# %%
coef1 = coef(cars.logistic)[1]
coef2 = coef(cars.logistic)[2]
coef3 = coef(cars.logistic)[3]

# %%
int.cars <- (-coef1/coef3)
slope.cars <- -coef2/coef3

# %%
plot(wt ~ mpg, data=mtcars, pch = am)
abline(int.cars,slope.cars)
# Out:
# plot without title

# %%
iris
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1   5.1          3.5         1.4          0.2         setosa
# 2   4.9          3.0         1.4          0.2         setosa
# 3   4.7          3.2         1.3          0.2         setosa
# 4   4.6          3.1         1.5          0.2         setosa
# 5   5.0          3.6         1.4          0.2         setosa
# 6   5.4          3.9         1.7          0.4         setosa
# 7   4.6          3.4         1.4          0.3         setosa
# 8   5.0          3.4         1.5          0.2         setosa
# 9   4.4          2.9         1.4          0.2         setosa
# 10  4.9          3.1         1.5          0.1         setosa
# 11  5.4          3.7         1.5          0.2         setosa
# 12  4.8          3.4         1.6          0.2         setosa
# 13  4.8          3.0         1.4          0.1         setosa
# 14  4.3          3.0         1.1          0.1         setosa
# 15  5.8          4.0         1.2          0.2         setosa
# 16  5.7          4.4         1.5          0.4         setosa
# 17  5.4          3.9         1.3          0.4         setosa
# 18  5.1          3.5         1.4          0.3         setosa
# 19  5.7          3.8         1.7          0.3         setosa
# 20  5.1          3.8         1.5          0.3         setosa
# 21  5.4          3.4         1.7          0.2         setosa
# 22  5.1          3.7         1.5          0.4         setosa
# 23  4.6          3.6         1.0          0.2         setosa
# 24  5.1          3.3         1.7          0.5         setosa
# 25  4.8          3.4         1.9          0.2         setosa
# 26  5.0          3.0         1.6          0.2         setosa
# 27  5.0          3.4         1.6          0.4         setosa
# 28  5.2          3.5         1.5          0.2         setosa
# 29  5.2          3.4         1.4          0.2         setosa
# 30  4.7          3.2         1.6          0.2         setosa
# ⋮   ⋮            ⋮           ⋮            ⋮           ⋮
# 121 6.9          3.2         5.7          2.3         virginica
# 122 5.6          2.8         4.9          2.0         virginica
# 123 7.7          2.8         6.7          2.0         virginica
# 124 6.3          2.7         4.9          1.8         virginica
# 125 6.7          3.3         5.7          2.1         virginica
# 126 7.2          3.2         6.0          1.8         virginica
# 127 6.2          2.8         4.8          1.8         virginica
# 128 6.1          3.0         4.9          1.8         virginica
# 129 6.4          2.8         5.6          2.1         virginica
# 130 7.2          3.0         5.8          1.6         virginica
# 131 7.4          2.8         6.1          1.9         virginica
# 132 7.9          3.8         6.4          2.0         virginica
# 133 6.4          2.8         5.6          2.2         virginica
# 134 6.3          2.8         5.1          1.5         virginica
# 135 6.1          2.6         5.6          1.4         virginica
# 136 7.7          3.0         6.1          2.3         virginica
# 137 6.3          3.4         5.6          2.4         virginica
# 138 6.4          3.1         5.5          1.8         virginica
# 139 6.0          3.0         4.8          1.8         virginica
# 140 6.9          3.1         5.4          2.1         virginica
# 141 6.7          3.1         5.6          2.4         virginica
# 142 6.9          3.1         5.1          2.3         virginica
# 143 5.8          2.7         5.1          1.9         virginica
# 144 6.8          3.2         5.9          2.3         virginica
# 145 6.7          3.3         5.7          2.5         virginica
# 146 6.7          3.0         5.2          2.3         virginica
# 147 6.3          2.5         5.0          1.9         virginica
# 148 6.5          3.0         5.2          2.0         virginica
# 149 6.2          3.4         5.4          2.3         virginica
# 150 5.9          3.0         5.1          1.8         virginica

# %%
write.csv(iris, 'iris.csv')

# %%
library(party)
# Out:
# Error in library(party): there is no package called ‘party’
# Traceback:
#
# 1. library(party)
# 2. stop(txt, domain = NA)

# %%
install.packages(party)
# Out:
# Error in install.packages(party): object 'party' not found
# Traceback:
#
# 1. install.packages(party)

# %%
library(party)
tree <- ctree(mpg ~ ., data = mtcars)
plot(tree)
# Out:
# Loading required package: grid
# Loading required package: mvtnorm
# Loading required package: modeltools
# Loading required package: stats4
# Loading required package: strucchange
# Loading required package: zoo
#
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
# Loading required package: sandwich
# plot without title

# %%
?mtcars

# %%
tree <- ctree(mpg ~ ., data = mtcars)
plot(tree)

# %%
as.factor(iris$Species)
# Out:
#   [1] setosa     setosa     setosa     setosa     setosa     setosa
#   [7] setosa     setosa     setosa     setosa     setosa     setosa
#  [13] setosa     setosa     setosa     setosa     setosa     setosa
#  [19] setosa     setosa     setosa     setosa     setosa     setosa
#  [25] setosa     setosa     setosa     setosa     setosa     setosa
#  [31] setosa     setosa     setosa     setosa     setosa     setosa
#  [37] setosa     setosa     setosa     setosa     setosa     setosa
#  [43] setosa     setosa     setosa     setosa     setosa     setosa
#  [49] setosa     setosa     versicolor versicolor versicolor versicolor
#  [55] versicolor versicolor versicolor versicolor versicolor versicolor
#  [61] versicolor versicolor versicolor versicolor versicolor versicolor
#  [67] versicolor versicolor versicolor versicolor versicolor versicolor
#  [73] versicolor versicolor versicolor versicolor versicolor versicolor
#  [79] versicolor versicolor versicolor versicolor versicolor versicolor
#  [85] versicolor versicolor versicolor versicolor versicolor versicolor
#  [91] versicolor versicolor versicolor versicolor versicolor versicolor
#  [97] versicolor versicolor versicolor versicolor virginica  virginica
# [103] virginica  virginica  virginica  virginica  virginica  virginica
# [109] virginica  virginica  virginica  virginica  virginica  virginica
# [115] virginica  virginica  virginica  virginica  virginica  virginica
# [121] virginica  virginica  virginica  virginica  virginica  virginica
# [127] virginica  virginica  virginica  virginica  virginica  virginica
# [133] virginica  virginica  virginica  virginica  virginica  virginica
# [139] virginica  virginica  virginica  virginica  virginica  virginica
# [145] virginica  virginica  virginica  virginica  virginica  virginica
# Levels: setosa versicolor virginica

# %%
iris$Species <- as.factor(iris$Species)

# %%
iris$Species
# Out:
#   [1] setosa     setosa     setosa     setosa     setosa     setosa
#   [7] setosa     setosa     setosa     setosa     setosa     setosa
#  [13] setosa     setosa     setosa     setosa     setosa     setosa
#  [19] setosa     setosa     setosa     setosa     setosa     setosa
#  [25] setosa     setosa     setosa     setosa     setosa     setosa
#  [31] setosa     setosa     setosa     setosa     setosa     setosa
#  [37] setosa     setosa     setosa     setosa     setosa     setosa
#  [43] setosa     setosa     setosa     setosa     setosa     setosa
#  [49] setosa     setosa     versicolor versicolor versicolor versicolor
#  [55] versicolor versicolor versicolor versicolor versicolor versicolor
#  [61] versicolor versicolor versicolor versicolor versicolor versicolor
#  [67] versicolor versicolor versicolor versicolor versicolor versicolor
#  [73] versicolor versicolor versicolor versicolor versicolor versicolor
#  [79] versicolor versicolor versicolor versicolor versicolor versicolor
#  [85] versicolor versicolor versicolor versicolor versicolor versicolor
#  [91] versicolor versicolor versicolor versicolor versicolor versicolor
#  [97] versicolor versicolor versicolor versicolor virginica  virginica
# [103] virginica  virginica  virginica  virginica  virginica  virginica
# [109] virginica  virginica  virginica  virginica  virginica  virginica
# [115] virginica  virginica  virginica  virginica  virginica  virginica
# [121] virginica  virginica  virginica  virginica  virginica  virginica
# [127] virginica  virginica  virginica  virginica  virginica  virginica
# [133] virginica  virginica  virginica  virginica  virginica  virginica
# [139] virginica  virginica  virginica  virginica  virginica  virginica
# [145] virginica  virginica  virginica  virginica  virginica  virginica
# Levels: setosa versicolor virginica

# %%
library(party)

iris.tree <- ctree(Species ~ Sepal.Length, data=iris)

plot(iris.tree)
# Out:
# plot without title

# %%
iris
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1   5.1          3.5         1.4          0.2         setosa
# 2   4.9          3.0         1.4          0.2         setosa
# 3   4.7          3.2         1.3          0.2         setosa
# 4   4.6          3.1         1.5          0.2         setosa
# 5   5.0          3.6         1.4          0.2         setosa
# 6   5.4          3.9         1.7          0.4         setosa
# 7   4.6          3.4         1.4          0.3         setosa
# 8   5.0          3.4         1.5          0.2         setosa
# 9   4.4          2.9         1.4          0.2         setosa
# 10  4.9          3.1         1.5          0.1         setosa
# 11  5.4          3.7         1.5          0.2         setosa
# 12  4.8          3.4         1.6          0.2         setosa
# 13  4.8          3.0         1.4          0.1         setosa
# 14  4.3          3.0         1.1          0.1         setosa
# 15  5.8          4.0         1.2          0.2         setosa
# 16  5.7          4.4         1.5          0.4         setosa
# 17  5.4          3.9         1.3          0.4         setosa
# 18  5.1          3.5         1.4          0.3         setosa
# 19  5.7          3.8         1.7          0.3         setosa
# 20  5.1          3.8         1.5          0.3         setosa
# 21  5.4          3.4         1.7          0.2         setosa
# 22  5.1          3.7         1.5          0.4         setosa
# 23  4.6          3.6         1.0          0.2         setosa
# 24  5.1          3.3         1.7          0.5         setosa
# 25  4.8          3.4         1.9          0.2         setosa
# 26  5.0          3.0         1.6          0.2         setosa
# 27  5.0          3.4         1.6          0.4         setosa
# 28  5.2          3.5         1.5          0.2         setosa
# 29  5.2          3.4         1.4          0.2         setosa
# 30  4.7          3.2         1.6          0.2         setosa
# ⋮   ⋮            ⋮           ⋮            ⋮           ⋮
# 121 6.9          3.2         5.7          2.3         virginica
# 122 5.6          2.8         4.9          2.0         virginica
# 123 7.7          2.8         6.7          2.0         virginica
# 124 6.3          2.7         4.9          1.8         virginica
# 125 6.7          3.3         5.7          2.1         virginica
# 126 7.2          3.2         6.0          1.8         virginica
# 127 6.2          2.8         4.8          1.8         virginica
# 128 6.1          3.0         4.9          1.8         virginica
# 129 6.4          2.8         5.6          2.1         virginica
# 130 7.2          3.0         5.8          1.6         virginica
# 131 7.4          2.8         6.1          1.9         virginica
# 132 7.9          3.8         6.4          2.0         virginica
# 133 6.4          2.8         5.6          2.2         virginica
# 134 6.3          2.8         5.1          1.5         virginica
# 135 6.1          2.6         5.6          1.4         virginica
# 136 7.7          3.0         6.1          2.3         virginica
# 137 6.3          3.4         5.6          2.4         virginica
# 138 6.4          3.1         5.5          1.8         virginica
# 139 6.0          3.0         4.8          1.8         virginica
# 140 6.9          3.1         5.4          2.1         virginica
# 141 6.7          3.1         5.6          2.4         virginica
# 142 6.9          3.1         5.1          2.3         virginica
# 143 5.8          2.7         5.1          1.9         virginica
# 144 6.8          3.2         5.9          2.3         virginica
# 145 6.7          3.3         5.7          2.5         virginica
# 146 6.7          3.0         5.2          2.3         virginica
# 147 6.3          2.5         5.0          1.9         virginica
# 148 6.5          3.0         5.2          2.0         virginica
# 149 6.2          3.4         5.4          2.3         virginica
# 150 5.9          3.0         5.1          1.8         virginica

# %%
iris.tree <- ctree(Species ~ ., data=iris)

plot(iris.tree)
# Out:
# plot without title

# %%
library(e1071)
# Out:
# Error in library(e1071): there is no package called ‘e1071’
# Traceback:
#
# 1. library(e1071)
# 2. stop(txt, domain = NA)

# %%
library(e1071)

# %%
summary(svmfit)
# Out:
# Call:
# svm(formula = Species ~ ., data = iris_train, kernel = "linear")
#
#
# Parameters:
#    SVM-Type:  C-classification
#  SVM-Kernel:  linear
#        cost:  1
#       gamma:  0.5
#
# Number of Support Vectors:  25
#
#  ( 12 2 11 )
#
#
# Number of Classes:  3
#
# Levels:
#  setosa versicolor virginica

# %%
iris_train
# Out:
#     Petal.Length Petal.Width Species
# 79  4.5          1.5         versicolor
# 137 5.6          2.4         virginica
# 144 5.9          2.3         virginica
# 32  1.5          0.4         setosa
# 100 4.1          1.3         versicolor
# 97  4.2          1.3         versicolor
# 86  4.5          1.6         versicolor
# 27  1.6          0.4         setosa
# 84  5.1          1.6         versicolor
# 73  4.9          1.5         versicolor
# 71  4.8          1.8         versicolor
# 117 5.5          1.8         virginica
# 76  4.4          1.4         versicolor
# 66  4.4          1.4         versicolor
# 34  1.4          0.2         setosa
# 114 5.0          2.0         virginica
# 108 6.3          1.8         virginica
# 28  1.5          0.2         setosa
# 12  1.6          0.2         setosa
# 60  3.9          1.4         versicolor
# 39  1.3          0.2         setosa
# 134 5.1          1.5         virginica
# 90  4.0          1.3         versicolor
# 58  3.3          1.0         versicolor
# 98  4.3          1.3         versicolor
# 145 5.7          2.5         virginica
# 62  4.2          1.5         versicolor
# 88  4.4          1.3         versicolor
# 21  1.7          0.2         setosa
# 105 5.8          2.2         virginica
# ⋮   ⋮            ⋮           ⋮
# 110 6.1          2.5         virginica
# 17  1.3          0.4         setosa
# 83  3.9          1.2         versicolor
# 15  1.2          0.2         setosa
# 78  5.0          1.7         versicolor
# 14  1.1          0.1         setosa
# 92  4.6          1.4         versicolor
# 2   1.4          0.2         setosa
# 46  1.4          0.3         setosa
# 30  1.6          0.2         setosa
# 65  3.6          1.3         versicolor
# 1   1.4          0.2         setosa
# 68  4.1          1.0         versicolor
# 77  4.8          1.4         versicolor
# 45  1.9          0.4         setosa
# 130 5.8          1.6         virginica
# 113 5.5          2.1         virginica
# 129 5.6          2.1         virginica
# 81  3.8          1.1         versicolor
# 99  3.0          1.1         versicolor
# 122 4.9          2.0         virginica
# 25  1.9          0.2         setosa
# 146 5.2          2.3         virginica
# 121 5.7          2.3         virginica
# 96  4.2          1.2         versicolor
# 125 5.7          2.1         virginica
# 49  1.5          0.2         setosa
# 120 5.0          1.5         virginica
# 149 5.4          2.3         virginica
# 44  1.6          0.6         setosa

# %%
s <- sample(150, 100) 
col <- c("Petal.Length", "Petal.Width", "Species")
iris_train <- iris[s, col]
iris_test <- iris[-s, col]
svmfit <- svm(Species ~ ., data = iris_train, kernel = "linear")
col <- c("Petal.Length", "Petal.Width", "Species")
plot(svmfit, iris_train[, col])
# Out:
# Plot with title “SVM classification plot”

# %%
summary(svmfit)
# Out:
# Call:
# svm(formula = Species ~ ., data = iris_train, kernel = "linear")
#
#
# Parameters:
#    SVM-Type:  C-classification
#  SVM-Kernel:  linear
#        cost:  1
#       gamma:  0.5
#
# Number of Support Vectors:  25
#
#  ( 12 10 3 )
#
#
# Number of Classes:  3
#
# Levels:
#  setosa versicolor virginica

# %%
class(iris_train$Species)
# Out:
# [1] "factor"

# %%
plot(svmfit, iris_train[, col])

# %%
summary(iris_test)
# Out:
#   Petal.Length    Petal.Width          Species
#  Min.   :1.000   Min.   :0.100   setosa    :16
#  1st Qu.:1.525   1st Qu.:0.200   versicolor:15
#  Median :4.550   Median :1.450   virginica :19
#  Mean   :3.808   Mean   :1.286
#  3rd Qu.:5.100   3rd Qu.:2.000
#  Max.   :6.400   Max.   :2.500

# %%
summary(iris_train)
# Out:
#   Petal.Length    Petal.Width          Species
#  Min.   :1.200   Min.   :0.100   setosa    :34
#  1st Qu.:1.600   1st Qu.:0.300   versicolor:35
#  Median :4.200   Median :1.300   virginica :31
#  Mean   :3.733   Mean   :1.156
#  3rd Qu.:5.100   3rd Qu.:1.800
#  Max.   :6.900   Max.   :2.500

# %%
summary(iris)
# Out:
#   Sepal.Length    Sepal.Width     Petal.Length    Petal.Width
#  Min.   :4.300   Min.   :2.000   Min.   :1.000   Min.   :0.100
#  1st Qu.:5.100   1st Qu.:2.800   1st Qu.:1.600   1st Qu.:0.300
#  Median :5.800   Median :3.000   Median :4.350   Median :1.300
#  Mean   :5.843   Mean   :3.057   Mean   :3.758   Mean   :1.199
#  3rd Qu.:6.400   3rd Qu.:3.300   3rd Qu.:5.100   3rd Qu.:1.800
#  Max.   :7.900   Max.   :4.400   Max.   :6.900   Max.   :2.500
#        Species
#  setosa    :50
#  versicolor:50
#  virginica :50

# %%
iris.new <- iris[,c(1,2,3,4)]

# %%
iris[,c(1:4)]
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width
# 1   5.1          3.5         1.4          0.2
# 2   4.9          3.0         1.4          0.2
# 3   4.7          3.2         1.3          0.2
# 4   4.6          3.1         1.5          0.2
# 5   5.0          3.6         1.4          0.2
# 6   5.4          3.9         1.7          0.4
# 7   4.6          3.4         1.4          0.3
# 8   5.0          3.4         1.5          0.2
# 9   4.4          2.9         1.4          0.2
# 10  4.9          3.1         1.5          0.1
# 11  5.4          3.7         1.5          0.2
# 12  4.8          3.4         1.6          0.2
# 13  4.8          3.0         1.4          0.1
# 14  4.3          3.0         1.1          0.1
# 15  5.8          4.0         1.2          0.2
# 16  5.7          4.4         1.5          0.4
# 17  5.4          3.9         1.3          0.4
# 18  5.1          3.5         1.4          0.3
# 19  5.7          3.8         1.7          0.3
# 20  5.1          3.8         1.5          0.3
# 21  5.4          3.4         1.7          0.2
# 22  5.1          3.7         1.5          0.4
# 23  4.6          3.6         1.0          0.2
# 24  5.1          3.3         1.7          0.5
# 25  4.8          3.4         1.9          0.2
# 26  5.0          3.0         1.6          0.2
# 27  5.0          3.4         1.6          0.4
# 28  5.2          3.5         1.5          0.2
# 29  5.2          3.4         1.4          0.2
# 30  4.7          3.2         1.6          0.2
# ⋮   ⋮            ⋮           ⋮            ⋮
# 121 6.9          3.2         5.7          2.3
# 122 5.6          2.8         4.9          2.0
# 123 7.7          2.8         6.7          2.0
# 124 6.3          2.7         4.9          1.8
# 125 6.7          3.3         5.7          2.1
# 126 7.2          3.2         6.0          1.8
# 127 6.2          2.8         4.8          1.8
# 128 6.1          3.0         4.9          1.8
# 129 6.4          2.8         5.6          2.1
# 130 7.2          3.0         5.8          1.6
# 131 7.4          2.8         6.1          1.9
# 132 7.9          3.8         6.4          2.0
# 133 6.4          2.8         5.6          2.2
# 134 6.3          2.8         5.1          1.5
# 135 6.1          2.6         5.6          1.4
# 136 7.7          3.0         6.1          2.3
# 137 6.3          3.4         5.6          2.4
# 138 6.4          3.1         5.5          1.8
# 139 6.0          3.0         4.8          1.8
# 140 6.9          3.1         5.4          2.1
# 141 6.7          3.1         5.6          2.4
# 142 6.9          3.1         5.1          2.3
# 143 5.8          2.7         5.1          1.9
# 144 6.8          3.2         5.9          2.3
# 145 6.7          3.3         5.7          2.5
# 146 6.7          3.0         5.2          2.3
# 147 6.3          2.5         5.0          1.9
# 148 6.5          3.0         5.2          2.0
# 149 6.2          3.4         5.4          2.3
# 150 5.9          3.0         5.1          1.8

# %%
cl <- kmeans(iris.new, centers = 3)

# %%
plot(iris.new[,c(1,2)], col=cl$cluster)
# Out:
# plot without title

# %%
df <- read.csv('./event-0005.csv')

# %%
df
# Out:
#     jet constituent eta       phi       px        py        pz
# 1   0    0          -0.456679 -1.769878 -0.178798 -0.886218 -0.427374
# 2   0    1          -0.451003 -1.770757 -0.180011 -0.888201 -0.422723
# 3   0    2          -0.455031 -1.657863 -0.078671 -0.901284 -0.426026
# 4   0    3          -0.452284 -1.651613 -0.073121 -0.902811 -0.423775
# 5   0    4          -0.446974 -1.658059 -0.079116 -0.904343 -0.419409
# 6   0    5          -0.452834 -1.767828 -0.177271 -0.888036 -0.424225
# 7   0    6          -0.443312 -1.663430 -0.084101 -0.905290 -0.416386
# 8   0    7          -0.572039 -1.440962  0.110835 -0.848868 -0.516855
# 9   0    8          -0.427564 -1.654641 -0.076634 -0.911860 -0.403284
# 10  0    9          -0.442030 -1.636672 -0.059882 -0.907700 -0.415326
# 11  0   10          -0.442030 -1.763335 -0.174067 -0.892864 -0.415326
# 12  0   11          -0.452284 -1.771147 -0.180260 -0.887649 -0.423775
# 13  0   12          -0.387463 -1.679544 -0.100867 -0.923872 -0.369171
# 14  0   13          -0.469680 -1.766168 -0.174525 -0.881901 -0.437941
# 15  0   14          -0.419141 -1.661966 -0.083592 -0.914348 -0.396207
# 16  0   15          -0.389660 -1.694096 -0.114207 -0.921556 -0.371067
# 17  0   16          -0.440748 -1.807478 -0.213412 -0.884783 -0.414265
# 18  0   17           0.182745 -1.497211  0.072308 -0.980870  0.180737
# 19  0   18          -0.657552 -1.876525 -0.245887 -0.779051 -0.576732
# 20  0   19          -0.408521 -2.019499 -0.399956 -0.830722 -0.387216
# 21  0   20          -0.570940 -1.963638 -0.327904 -0.791310 -0.516049
# 22  0   21          -0.339122 -1.612065 -0.038993 -0.944326 -0.326693
# 23  0   22          -0.540727 -1.630904 -0.052246 -0.868154 -0.493538
# 24  0   23          -0.024171 -1.663425 -0.092469 -0.995422 -0.024166
# 25  0   24          -0.302866 -1.415175  0.148148 -0.944275 -0.293933
# 26  0   25          -0.559587 -1.806007 -0.200782 -0.837828 -0.507671
# 27  0   26           0.210578 -1.527787  0.042061 -0.977326  0.207519
# 28  0   27          -0.439650 -1.886184 -0.282446 -0.865658 -0.413354
# 29  0   28           0.123417 -2.225159 -0.604048 -0.787431  0.122794
# 30  0   29           0.149602 -1.316650  0.248632 -0.957148  0.148496
# ⋮   ⋮   ⋮           ⋮         ⋮         ⋮         ⋮         ⋮
# 176 2   38          -0.705161 2.244106  -0.495256 0.620889  -0.607633
# 177 2   39          -0.484695 2.662673  -0.792559 0.411527  -0.449996
# 178 2   40          -0.607196 2.093820  -0.419722 0.727947  -0.542150
# 179 2   41          -0.490188 2.109055  -0.456669 0.764856  -0.454366
# 180 2   42          -0.519852 2.588159  -0.747434 0.461795  -0.477586
# 181 2   43          -0.523881 1.876223  -0.263681 0.836307  -0.480690
# 182 2   44          -0.705161 2.893064  -0.769816 0.195360  -0.607633
# 183 2   45          -0.461623 2.003667  -0.378436 0.818948  -0.431406
# 184 2   46          -0.463271 1.966653  -0.347624 0.831798  -0.432746
# 185 2   47          -0.311472 1.615080  -0.042205 0.952444  -0.301776
# 186 2   48          -0.809900 1.977396  -0.293761 0.682222  -0.669535
# 187 2   49          -0.453749 1.896241  -0.289421 0.857689  -0.424976
# 188 2   50          -0.293710 2.153280  -0.527196 0.800330  -0.285546
# 189 2   51          -0.484146 2.066167  -0.424614 0.785876  -0.449558
# 190 2   52          -0.786279 2.204958  -0.447045 0.607804  -0.656296
# 191 2   53          -0.709555 2.408089  -0.588395 0.530289  -0.610398
# 192 2   54          -0.700583 2.606420  -0.685069 0.406168  -0.604738
# 193 2   55          -0.918851 1.877101  -0.207571 0.656336  -0.725354
# 194 2   56          -0.923429 2.462387  -0.533828 0.430986  -0.727516
# 195 2   57          -0.911344 2.136595  -0.371042 0.584266  -0.721777
# 196 2   58          -1.280862 1.909146  -0.171207 0.486548  -0.856714
# 197 2   59          -0.718711 1.623189  -0.041249 0.786579  -0.616110
# 198 2   60          -0.461989 1.831106  -0.232160 0.871627  -0.431704
# 199 2   61          -0.842860 2.416768  -0.543760 0.481576  -0.687321
# 200 2   62          -0.486160 1.932876  -0.316121 0.834577  -0.451163
# 201 2   63          -0.284188 2.119112  -0.500888 0.820065  -0.276777
# 202 2   64          -0.467483 1.804063  -0.208011 0.875496  -0.436163
# 203 2   65          -1.056368 1.734522  -0.101125 0.612123  -0.784270
# 204 2   66          -1.050142 2.005722  -0.262687 0.565410  -0.781862
# 205 2   67          -1.098300 2.606918  -0.516390 0.305813  -0.799888
#     p          vjet
# 1   788.651301 NaN
# 2   234.618344 NaN
# 3   122.207524 NaN
# 4    99.432245 NaN
# 5    91.636616 NaN
# 6    54.524478 NaN
# 7    42.207993 NaN
# 8    38.037065 NaN
# 9    28.532498 NaN
# 10   24.390640 NaN
# 11   22.724518 NaN
# 12   21.425199 NaN
# 13   16.341865 NaN
# 14   15.998610 NaN
# 15   13.231267 NaN
# 16   10.970746 NaN
# 17   11.150211 NaN
# 18    4.277475 NaN
# 19    3.853970 NaN
# 20    3.003866 NaN
# 21    3.167197 NaN
# 22    2.663736 NaN
# 23    2.177190 NaN
# 24    1.883363 NaN
# 25    1.922830 NaN
# 26    2.117366 NaN
# 27    1.798927 NaN
# 28    1.769581 NaN
# 29    1.510454 NaN
# 30    1.184026 NaN
# ⋮   ⋮          ⋮
# 176 2.200967   NaN
# 177 1.936655   NaN
# 178 1.996634   NaN
# 179 1.827461   NaN
# 180 1.805104   NaN
# 181 1.806364   NaN
# 182 1.881273   NaN
# 183 1.531701   NaN
# 184 1.296644   NaN
# 185 1.219962   NaN
# 186 1.550078   NaN
# 187 1.232025   NaN
# 188 0.963453   NaN
# 189 1.014005   NaN
# 190 1.129287   NaN
# 191 1.025144   NaN
# 192 0.901858   NaN
# 193 1.037030   NaN
# 194 1.007035   NaN
# 195 0.974974   NaN
# 196 1.197531   NaN
# 197 0.666407   NaN
# 198 0.564599   NaN
# 199 0.700470   NaN
# 200 0.555610   NaN
# 201 0.470276   NaN
# 202 0.462579   NaN
# 203 0.593017   NaN
# 204 0.508290   NaN
# 205 0.403952   NaN
